# %%
import torch

# %%
print(torch.cuda.is_available())
# Out:
# True

# %%
from mmsdk import mmdatasdk as md
DATASET = md.cmu_mosi
DATA_PATH = 'cmu_mosi_raw/'
md.mmdataset(DATASET.raw,DATA_PATH)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[6], line 4
#       2 DATASET = md.cmu_mosi
#       3 DATA_PATH = 'cmu_mosi_raw/'
# ----> 4 md.mmdataset(DATASET.raw,DATA_PATH)
#
# File F:\ProgramData\anaconda3\envs\deeplearning\lib\site-packages\mmsdk\mmdatasdk\dataset\dataset.py:30, in mmdataset.__init__(self, recipe, destination)
#      28 elif type(recipe) is dict:
#      29 	for entry, address in recipe.items():
# ---> 30 		self.computational_sequences[entry]=computational_sequence(address,destination)
#      32 elif type(recipe) is list:
#      33 	#TODO: computational sequence with uuid
#      34 	pass
#
# File F:\ProgramData\anaconda3\envs\deeplearning\lib\site-packages\mmsdk\mmdatasdk\computational_sequence\computational_sequence.py:33, in computational_sequence.__init__(self, resource, destination, validate)
#      31 def __init__(self,resource, destination=None, validate=True):
#      32 	#initializing the featureset
# ---> 33 	self.__initialize(resource,destination,validate)
#      35 	#BACKWARD: backward compatibility
#      36 	self.rootName=self.root_name
#
# File F:\ProgramData\anaconda3\envs\deeplearning\lib\site-packages\mmsdk\mmdatasdk\computational_sequence\computational_sequence.py:116, in computational_sequence.__initialize(self, resource, destination, validate)
#     113 	self.__initialize_blank(resource)
#     114 #reading from url or folder - main_file is where the data should go and resource is the url
#     115 else:
# --> 116 	self.__initialize_from_csd(resource,destination,validate)
#
# File F:\ProgramData\anaconda3\envs\deeplearning\lib\site-packages\mmsdk\mmdatasdk\computational_sequence\computational_sequence.py:76, in computational_sequence.__initialize_from_csd(self, resource, destination, validate)
#      72 #.csd cannot be in the destination as we don't allow name changes when downloading
#      73 else:
#      74 	log.error("Destination needs to be a folder where the downloaded computational sequence is stored. Exiting ...!",error=True)
# ---> 76 read_URL(resource,destination)
#      77 self.resource=resource
#      78 self.main_file=destination
#
# File F:\ProgramData\anaconda3\envs\deeplearning\lib\site-packages\mmsdk\mmdatasdk\computational_sequence\download_ops.py:15, in read_URL(url, destination)
#      12 if destination is None:
#      13 	log.error("Destination is not specified when downloading data",error=True)
# ---> 15 if os.path.isdir(destination.rsplit('/',1)[-2]) is False:
#      16 	os.mkdir(destination.rsplit('/',1)[-2])
#      18 if(os.path.isfile(destination)):
#
# IndexError: list index out of range

# %%
torch.cuda.is_available()
# Out:
# True

# %%
from mmsdk import mmdatasdk as md
import os
import torch
import numpy as np

# %%
DATASET = md.cmu_mosi
DATA_PATH = 'C:/Users/Administrator/PycharmProjects/demo1/cmu_mosi'
data_files = os.listdir(DATA_PATH)
print('\n'.join(data_files))
# Out:
# CMU_MOSI_COVAREP.csd
# CMU_MOSI_OpenSmile_EB10.csd
# CMU_MOSI_openSMILE_IS09.csd
# CMU_MOSI_TimestampedWordVectors.csd
# CMU_MOSI_Visual_Facet_41.csd
# CMU_MOSI_Visual_Facet_42.csd
# CMU_MOSI_Visual_OpenFace_1.csd
# CMU_MOSI_Visual_OpenFace_2.csd

# %%
visual_field = 'CMU_MOSI_Visual_Facet_41'
acoustic_field = 'CMU_MOSI_COVAREP'
text_field = 'CMU_MOSI_TimestampedWordVectors'

# %%
features = [
    text_field,
    visual_field,
    acoustic_field
]
recipe = {feat: os.path.join(DATA_PATH, feat) + '.csd' for feat in features}

# %%
recipe
import torch.
# Out:
# {'CMU_MOSI_TimestampedWordVectors': 'C:/Users/Administrator/PycharmProjects/demo1/cmu_mosi\\CMU_MOSI_TimestampedWordVectors.csd',
#  'CMU_MOSI_Visual_Facet_41': 'C:/Users/Administrator/PycharmProjects/demo1/cmu_mosi\\CMU_MOSI_Visual_Facet_41.csd',
#  'CMU_MOSI_COVAREP': 'C:/Users/Administrator/PycharmProjects/demo1/cmu_mosi\\CMU_MOSI_COVAREP.csd'}

# %%
dataset = md.mmdataset(recipe)
print(list(dataset[text_field].keys())[55])
# Out:
# [2024-04-10 08:37:04.218] | Success | Computational sequence read from file C:/Users/Administrator/PycharmProjects/demo1/cmu_mosi\CMU_MOSI_TimestampedWordVectors.csd ...
# [2024-04-10 08:37:04.236] | Status  | Checking the integrity of the <glove_vectors> computational sequence ...
# [2024-04-10 08:37:04.236] | Status  | Checking the format of the data in <glove_vectors> computational sequence ...
# [2024-04-10 08:37:04.299] | Success | <glove_vectors> computational sequence data in correct format.
# [2024-04-10 08:37:04.299] | Status  | Checking the format of the metadata in <glove_vectors> computational sequence ...
# [2024-04-10 08:37:04.299] | Warning | <glove_vectors> computational sequence does not have all the required metadata ... continuing
# [2024-04-10 08:37:04.300] | Success | Computational sequence read from file C:/Users/Administrator/PycharmProjects/demo1/cmu_mosi\CMU_MOSI_Visual_Facet_41.csd ...
# [2024-04-10 08:37:04.317] | Status  | Checking the integrity of the <FACET_4.1> computational sequence ...
# [2024-04-10 08:37:04.317] | Status  | Checking the format of the data in <FACET_4.1> computational sequence ...
# [2024-04-10 08:37:04.390] | Success | <FACET_4.1> computational sequence data in correct format.
# [2024-04-10 08:37:04.390] | Status  | Checking the format of the metadata in <FACET_4.1> computational sequence ...
# [2024-04-10 08:37:04.390] | Warning | <FACET_4.1> computational sequence does not have all the required metadata ... continuing
# [2024-04-10 08:37:04.391] | Success | Computational sequence read from file C:/Users/Administrator/PycharmProjects/demo1/cmu_mosi\CMU_MOSI_COVAREP.csd ...
# [2024-04-10 08:37:04.405] | Status  | Checking the integrity of the <COVAREP> computational sequence ...
# [2024-04-10 08:37:04.405] | Status  | Checking the format of the data in <COVAREP> computational sequence ...
# [2024-04-10 08:37:04.460] | Success | <COVAREP> computational sequence data in correct format.
# [2024-04-10 08:37:04.460] | Status  | Checking the format of the metadata in <COVAREP> computational sequence ...
# [2024-04-10 08:37:04.460] | Warning | <COVAREP> computational sequence does not have all the required metadata ... continuing
# [2024-04-10 08:37:04.460] | Success | Dataset initialized successfully ...
# ZUXBRvtny7o

# %%
print(list(dataset[text_field].keys())[55])
# Out:
# ZUXBRvtny7o

# %%
dataset[text_field].data
# Out:
# {'03bSnISJMiM': <HDF5 group "/glove_vectors/data/03bSnISJMiM" (2 members)>,
#  '0h-zjBukYpk': <HDF5 group "/glove_vectors/data/0h-zjBukYpk" (2 members)>,
#  '1DmNV9C1hbY': <HDF5 group "/glove_vectors/data/1DmNV9C1hbY" (2 members)>,
#  '1iG0909rllw': <HDF5 group "/glove_vectors/data/1iG0909rllw" (2 members)>,
#  '2WGyTLYerpo': <HDF5 group "/glove_vectors/data/2WGyTLYerpo" (2 members)>,
#  '2iD-tVS8NPw': <HDF5 group "/glove_vectors/data/2iD-tVS8NPw" (2 members)>,
#  '5W7Z1C_fDaE': <HDF5 group "/glove_vectors/data/5W7Z1C_fDaE" (2 members)>,
#  '6Egk_28TtTM': <HDF5 group "/glove_vectors/data/6Egk_28TtTM" (2 members)>,
#  '6_0THN4chvY': <HDF5 group "/glove_vectors/data/6_0THN4chvY" (2 members)>,
#  '73jzhE8R1TQ': <HDF5 group "/glove_vectors/data/73jzhE8R1TQ" (2 members)>,
#  '7JsX8y1ysxY': <HDF5 group "/glove_vectors/data/7JsX8y1ysxY" (2 members)>,
#  '8OtFthrtaJM': <HDF5 group "/glove_vectors/data/8OtFthrtaJM" (2 members)>,
#  '8d-gEyoeBzc': <HDF5 group "/glove_vectors/data/8d-gEyoeBzc" (2 members)>,
#  '8qrpnFRGt2A': <HDF5 group "/glove_vectors/data/8qrpnFRGt2A" (2 members)>,
#  '9J25DZhivz8': <HDF5 group "/glove_vectors/data/9J25DZhivz8" (2 members)>,
#  '9T9Hf74oK10': <HDF5 group "/glove_vectors/data/9T9Hf74oK10" (2 members)>,
#  '9c67fiY0wGQ': <HDF5 group "/glove_vectors/data/9c67fiY0wGQ" (2 members)>,
#  '9qR7uwkblbs': <HDF5 group "/glove_vectors/data/9qR7uwkblbs" (2 members)>,
#  'Af8D0E4ZXaw': <HDF5 group "/glove_vectors/data/Af8D0E4ZXaw" (2 members)>,
#  'BI97DNYfe5I': <HDF5 group "/glove_vectors/data/BI97DNYfe5I" (2 members)>,
#  'BXuRRbG0Ugk': <HDF5 group "/glove_vectors/data/BXuRRbG0Ugk" (2 members)>,
#  'Bfr499ggo-0': <HDF5 group "/glove_vectors/data/Bfr499ggo-0" (2 members)>,
#  'BioHAh1qJAQ': <HDF5 group "/glove_vectors/data/BioHAh1qJAQ" (2 members)>,
#  'BvYR0L6f2Ig': <HDF5 group "/glove_vectors/data/BvYR0L6f2Ig" (2 members)>,
#  'Ci-AH39fi3Y': <HDF5 group "/glove_vectors/data/Ci-AH39fi3Y" (2 members)>,
#  'Clx4VXItLTE': <HDF5 group "/glove_vectors/data/Clx4VXItLTE" (2 members)>,
#  'Dg_0XKD0Mf4': <HDF5 group "/glove_vectors/data/Dg_0XKD0Mf4" (2 members)>,
#  'G-xst2euQUc': <HDF5 group "/glove_vectors/data/G-xst2euQUc" (2 members)>,
#  'G6GlGvlkxAQ': <HDF5 group "/glove_vectors/data/G6GlGvlkxAQ" (2 members)>,
#  'GWuJjcEuzt8': <HDF5 group "/glove_vectors/data/GWuJjcEuzt8" (2 members)>,
#  'HEsqda8_d0Q': <HDF5 group "/glove_vectors/data/HEsqda8_d0Q" (2 members)>,
#  'I5y0__X72p0': <HDF5 group "/glove_vectors/data/I5y0__X72p0" (2 members)>,
#  'Iu2PFX3z_1s': <HDF5 group "/glove_vectors/data/Iu2PFX3z_1s" (2 members)>,
#  'IumbAb8q2dM': <HDF5 group "/glove_vectors/data/IumbAb8q2dM" (2 members)>,
#  'Jkswaaud0hk': <HDF5 group "/glove_vectors/data/Jkswaaud0hk" (2 members)>,
#  'LSi-o-IrDMs': <HDF5 group "/glove_vectors/data/LSi-o-IrDMs" (2 members)>,
#  'MLal-t_vJPM': <HDF5 group "/glove_vectors/data/MLal-t_vJPM" (2 members)>,
#  'Njd1F0vZSm4': <HDF5 group "/glove_vectors/data/Njd1F0vZSm4" (2 members)>,
#  'Nzq88NnDkEk': <HDF5 group "/glove_vectors/data/Nzq88NnDkEk" (2 members)>,
#  'OQvJTdtJ2H4': <HDF5 group "/glove_vectors/data/OQvJTdtJ2H4" (2 members)>,
#  'OtBXNcAL_lE': <HDF5 group "/glove_vectors/data/OtBXNcAL_lE" (2 members)>,
#  'Oz06ZWiO20M': <HDF5 group "/glove_vectors/data/Oz06ZWiO20M" (2 members)>,
#  'POKffnXeBds': <HDF5 group "/glove_vectors/data/POKffnXeBds" (2 members)>,
#  'PZ-lDQFboO8': <HDF5 group "/glove_vectors/data/PZ-lDQFboO8" (2 members)>,
#  'QN9ZIUWUXsY': <HDF5 group "/glove_vectors/data/QN9ZIUWUXsY" (2 members)>,
#  'Qr1Ca94K55A': <HDF5 group "/glove_vectors/data/Qr1Ca94K55A" (2 members)>,
#  'Sqr0AcuoNnk': <HDF5 group "/glove_vectors/data/Sqr0AcuoNnk" (2 members)>,
#  'TvyZBvOMOTc': <HDF5 group "/glove_vectors/data/TvyZBvOMOTc" (2 members)>,
#  'VCslbP0mgZI': <HDF5 group "/glove_vectors/data/VCslbP0mgZI" (2 members)>,
#  'VbQk4H8hgr0': <HDF5 group "/glove_vectors/data/VbQk4H8hgr0" (2 members)>,
#  'Vj1wYRQjB-o': <HDF5 group "/glove_vectors/data/Vj1wYRQjB-o" (2 members)>,
#  'W8NXH0Djyww': <HDF5 group "/glove_vectors/data/W8NXH0Djyww" (2 members)>,
#  'WKA5OygbEKI': <HDF5 group "/glove_vectors/data/WKA5OygbEKI" (2 members)>,
#  'X3j2zQgwYgE': <HDF5 group "/glove_vectors/data/X3j2zQgwYgE" (2 members)>,
#  'ZAIRrfG22O0': <HDF5 group "/glove_vectors/data/ZAIRrfG22O0" (2 members)>,
#  'ZUXBRvtny7o': <HDF5 group "/glove_vectors/data/ZUXBRvtny7o" (2 members)>,
#  '_dI--eQ6qVU': <HDF5 group "/glove_vectors/data/_dI--eQ6qVU" (2 members)>,
#  'aiEXnCPZubE': <HDF5 group "/glove_vectors/data/aiEXnCPZubE" (2 members)>,
#  'atnd_PF-Lbs': <HDF5 group "/glove_vectors/data/atnd_PF-Lbs" (2 members)>,
#  'bOL9jKpeJRs': <HDF5 group "/glove_vectors/data/bOL9jKpeJRs" (2 members)>,
#  'bvLlb-M3UXU': <HDF5 group "/glove_vectors/data/bvLlb-M3UXU" (2 members)>,
#  'c5xsKMxpXnc': <HDF5 group "/glove_vectors/data/c5xsKMxpXnc" (2 members)>,
#  'c7UH_rxdZv4': <HDF5 group "/glove_vectors/data/c7UH_rxdZv4" (2 members)>,
#  'cM3Yna7AavY': <HDF5 group "/glove_vectors/data/cM3Yna7AavY" (2 members)>,
#  'cW1FSBF59ik': <HDF5 group "/glove_vectors/data/cW1FSBF59ik" (2 members)>,
#  'cXypl4FnoZo': <HDF5 group "/glove_vectors/data/cXypl4FnoZo" (2 members)>,
#  'd3_k5Xpfmik': <HDF5 group "/glove_vectors/data/d3_k5Xpfmik" (2 members)>,
#  'd6hH302o4v8': <HDF5 group "/glove_vectors/data/d6hH302o4v8" (2 members)>,
#  'dq3Nf_lMPnE': <HDF5 group "/glove_vectors/data/dq3Nf_lMPnE" (2 members)>,
#  'etzxEpPuc6I': <HDF5 group "/glove_vectors/data/etzxEpPuc6I" (2 members)>,
#  'f9O3YtZ2VfI': <HDF5 group "/glove_vectors/data/f9O3YtZ2VfI" (2 members)>,
#  'f_pcplsH_V0': <HDF5 group "/glove_vectors/data/f_pcplsH_V0" (2 members)>,
#  'fvVhgmXxadc': <HDF5 group "/glove_vectors/data/fvVhgmXxadc" (2 members)>,
#  'iiK8YX8oH1E': <HDF5 group "/glove_vectors/data/iiK8YX8oH1E" (2 members)>,
#  'jUzDDGyPkXU': <HDF5 group "/glove_vectors/data/jUzDDGyPkXU" (2 members)>,
#  'k5Y_838nuGo': <HDF5 group "/glove_vectors/data/k5Y_838nuGo" (2 members)>,
#  'lXPQBPVc5Cw': <HDF5 group "/glove_vectors/data/lXPQBPVc5Cw" (2 members)>,
#  'nbWiPyCm4g0': <HDF5 group "/glove_vectors/data/nbWiPyCm4g0" (2 members)>,
#  'nzpVDcQ0ywM': <HDF5 group "/glove_vectors/data/nzpVDcQ0ywM" (2 members)>,
#  'ob23OKe5a9Q': <HDF5 group "/glove_vectors/data/ob23OKe5a9Q" (2 members)>,
#  'pLTX3ipuDJI': <HDF5 group "/glove_vectors/data/pLTX3ipuDJI" (2 members)>,
#  'phBUpBr1hSo': <HDF5 group "/glove_vectors/data/phBUpBr1hSo" (2 members)>,
#  'rnaNMUZpvvg': <HDF5 group "/glove_vectors/data/rnaNMUZpvvg" (2 members)>,
#  'tIrG4oNLFzE': <HDF5 group "/glove_vectors/data/tIrG4oNLFzE" (2 members)>,
#  'tStelxIAHjw': <HDF5 group "/glove_vectors/data/tStelxIAHjw" (2 members)>,
#  'tmZoasNr4rU': <HDF5 group "/glove_vectors/data/tmZoasNr4rU" (2 members)>,
#  'v0zCBqDeKcE': <HDF5 group "/glove_vectors/data/v0zCBqDeKcE" (2 members)>,
#  'vvZ4IcEtiZc': <HDF5 group "/glove_vectors/data/vvZ4IcEtiZc" (2 members)>,
#  'vyB00TXsimI': <HDF5 group "/glove_vectors/data/vyB00TXsimI" (2 members)>,
#  'wMbj6ajWbic': <HDF5 group "/glove_vectors/data/wMbj6ajWbic" (2 members)>,
#  'yDtzw_Y-7RU': <HDF5 group "/glove_vectors/data/yDtzw_Y-7RU" (2 members)>,
#  'yvsjCA6Y5Fc': <HDF5 group "/glove_vectors/data/yvsjCA6Y5Fc" (2 members)>,
#  'zhpQhgha_KU': <HDF5 group "/glove_vectors/data/zhpQhgha_KU" (2 members)>}

# %%
dataset[text_field]['ZUXBRvtny7o']['intervals']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[58], line 1
# ----> 1 dataset[text_field]['ZUXBRvtny7o']['intervals']
#
# File F:\ProgramData\anaconda3\envs\deeplearning\lib\site-packages\mmsdk\mmdatasdk\computational_sequence\computational_sequence.py:42, in computational_sequence.__getitem__(self, key)
#      41 def __getitem__(self, key):
# ---> 42 	return self.data[key]
#
# KeyError: 'ZUXBRvtny7o'

# %%
help(md.mmdataset.align)
# Out:
# Help on function align in module mmsdk.mmdatasdk.dataset.dataset:
#
# align(self, reference, collapse_functions=None, replace=True)

# %%
def avg(intervals: np.array, features: np.array) -> np.array:
    try:
        return np.average(features, axis=0)
    except:
        return features
 
# first we align to words with averaging, collapse_function receives a list of functions
dataset.align(text_field, collapse_functions=[avg])
# Out:
# [2024-04-10 10:06:00.017] | Status  | Unify was called ...
# [2024-04-10 10:06:00.017] | Success | Unify completed ...
# [2024-04-10 10:06:00.017] | Status  | Pre-alignment based on <CMU_MOSI_TimestampedWordVectors> computational sequence started ...
# [2024-04-10 10:06:00.898] | Status  | Pre-alignment done for <CMU_MOSI_Visual_Facet_41> ...
# [2024-04-10 10:06:04.305] | Status  | Pre-alignment done for <CMU_MOSI_COVAREP> ...
# [2024-04-10 10:06:04.347] | Status  | Alignment starting ...
# Overall Progress:   0%|                                            | 0/93 [00:00<?, ? Computational Sequence Entries/s]
#   0%|                                                                                   | 0/464 [00:00<?, ? Segments/s]
# Aligning 03bSnISJMiM:   0%|                                                             | 0/464 [00:00<?, ? Segments/s]
# Aligning 03bSnISJMiM:  10%|█████▏                                             | 47/464 [00:00<00:00, 457.53 Segments/s]
# Aligning 03bSnISJMiM:  21%|██████████▊                                        | 98/464 [00:00<00:00, 485.99 Segments/s]
# Aligning 03bSnISJMiM:  32%|███████████████▉                                  | 148/464 [00:00<00:00, 491.55 Segments/s]
# Aligning 03bSnISJMiM:  43%|█████████████████████▎                            | 198/464 [00:00<00:00, 481.10 Segments/s]
# Aligning 03bSnISJMiM:  53%|██████████████████████████▌                       | 247/464 [00:00<00:00, 482.94 Segments/s]
# Aligning 03bSnISJMiM:  64%|███████████████████████████████▉                  | 296/464 [00:00<00:00, 484.11 Segments/s]
# Aligning 03bSnISJMiM:  75%|█████████████████████████████████████▍            | 347/464 [00:00<00:00, 489.74 Segments/s]
# Aligning 03bSnISJMiM:  86%|███████████████████████████████████████████       | 400/464 [00:00<00:00, 501.25 Segments/s]
# Aligning 03bSnISJMiM:  97%|████████████████████████████████████████████████▌ | 451/464 [00:00<00:00, 489.92 Segments/s]
# Overall Progress:   1%|▍                                   | 1/93 [00:00<01:28,  1.04 Computational Sequence Entries/s]
#   0%|                                                                                   | 0/485 [00:00<?, ? Segments/s]
# Aligning 0h-zjBukYpk:   0%|                                                             | 0/485 [00:00<?, ? Segments/s]
# Aligning 0h-zjBukYpk:  10%|█████▏                                             | 49/485 [00:00<00:00, 481.53 Segments/s]
# Aligning 0h-zjBukYpk:  20%|██████████▎                                        | 98/485 [00:00<00:00, 485.95 Segments/s]
# Aligning 0h-zjBukYpk:  30%|███████████████▏                                  | 147/485 [00:00<00:00, 486.93 Segments/s]
# Aligning 0h-zjBukYpk:  40%|████████████████████▏                             | 196/485 [00:00<00:00, 487.48 Segments/s]
# Aligning 0h-zjBukYpk:  51%|█████████████████████████▎                        | 245/485 [00:00<00:00, 471.92 Segments/s]
# Aligning 0h-zjBukYpk:  61%|██████████████████████████████▍                   | 295/485 [00:00<00:00, 480.79 Segments/s]
# Aligning 0h-zjBukYpk:  71%|███████████████████████████████████▍              | 344/485 [00:00<00:00, 481.04 Segments/s]
# Aligning 0h-zjBukYpk:  81%|████████████████████████████████████████▌         | 393/485 [00:00<00:00, 479.79 Segments/s]
# Aligning 0h-zjBukYpk:  92%|█████████████████████████████████████████████▊    | 444/485 [00:00<00:00, 486.49 Segments/s]
# Overall Progress:   2%|▊                                   | 2/93 [00:01<01:29,  1.01 Computational Sequence Entries/s]
#   0%|                                                                                   | 0
[00:00<?, ? Segments/s]
# Aligning 8d-gEyoeBzc:   8%|████                                               | 47/584 [00:00<00:01, 461.84 Segments/s]
# Aligning 8d-gEyoeBzc:  16%|████████▏                                          | 94/584 [00:00<00:01, 466.07 Segments/s]
# Aligning 8d-gEyoeBzc:  25%|████████████▎                                     | 144/584 [00:00<00:00, 479.89 Segments/s]
# Aligning 8d-gEyoeBzc:  33%|████████████████▍                                 | 192/584 [00:00<00:00, 459.50 Segments/s]
# Aligning 8d-gEyoeBzc:  41%|████████████████████▋                             | 241/584 [00:00<00:00, 469.82 Segments/s]
# Aligning 8d-gEyoeBzc:  49%|████████████████████████▋                         | 289/584 [00:00<00:00, 429.40 Segments/s]
# Aligning 8d-gEyoeBzc:  58%|████████████████████████████▉                     | 338/584 [00:00<00:00, 446.68 Segments/s]
# Aligning 8d-gEyoeBzc:  66%|█████████████████████████████████▏                | 387/584 [00:00<00:00, 458.69 Segments/s]
# Aligning 8d-gEyoeBzc:  74%|█████████████████████████████████████▏            | 434/584 [00:00<00:00, 455.31 Segments/s]
# Aligning 8d-gEyoeBzc:  82%|█████████████████████████████████████████         | 480/584 [00:01<00:00, 453.63 Segments/s]
# Aligning 8d-gEyoeBzc:  90%|█████████████████████████████████████████████▏    | 528/584 [00:01<00:00, 460.41 Segments/s]
# Aligning 8d-gEyoeBzc:  98%|█████████████████████████████████████████████████▏| 575/584 [00:01<00:00, 447.71 Segments/s]
# Overall Progress:  14%|████▉                              | 13/93 [00:13<01:38,  1.23s/ Computational Sequence Entries]
#   0%|                                                                                   | 0/523 [00:00<?, ? Segments/s]
# Aligning 8qrpnFRGt2A:   0%|                                                             | 0/523 [00:00<?, ? Segments/s]
# Aligning 8qrpnFRGt2A:  10%|████▉                                              | 51/523 [00:00<00:00, 501.34 Segments/s]
# Aligning 8qrpnFRGt2A:  20%|█████████▊                                        | 102/523 [00:00<00:00, 499.78 Segments/s]
# Aligning 8qrpnFRGt2A:  29%|██████████████▌                                   | 152/523 [00:00<00:00, 497.05 Segments/s]
# Aligning 8qrpnFRGt2A:  39%|███████████████████▍                              | 203/523 [00:00<00:00, 498.71 Segments/s]
# Aligning 8qrpnFRGt2A:  48%|████████████████████████▏                         | 253/523 [00:00<00:00, 490.91 Segments/s]
# Aligning 8qrpnFRGt2A:  58%|█████████████████████████████                     | 304/523 [00:00<00:00, 496.67 Segments/s]
# Aligning 8qrpnFRGt2A:  68%|█████████████████████████████████▊                | 354/523 [00:00<00:00, 493.84 Segments/s]
# Aligning 8qrpnFRGt2A:  77%|██████████████████████████████████████▌           | 404/523 [00:00<00:00, 492.95 Segments/s]
# Aligning 8qrpnFRGt2A:  87%|███████████████████████████████████████████▍      | 454/523 [00:00<00:00, 480.70 Segments/s]
# Aligning 8qrpnFRGt2A:  96%|████████████████████████████████████████████████▏ | 504/523 [00:01<00:00, 485.45 Segments/s]
# Overall Progress:  15%|█████▎                             | 14/93 [00:14<01:33,  1.19s/ Computational Sequence Entries]
#   0%|                                                                                   | 0/554 [00:00<?, ? Segments/s]
# Aligning 9J25DZhivz8:   0%|                                                             | 0/554 [00:00<?, ? Segments/s]
# Aligning 9J25DZhivz8:   9%|████▍                                              | 48/554 [00:00<00:01, 471.70 Segments/s]
# Aligning 9J25DZhivz8:  17%|████████▊                                          | 96/554 [00:00<00:00, 471.78 Segments/s]
# Aligning 9J25DZhivz8:  27%|█████████████▎                                    | 147/554 [00:00<00:00, 487.53 Segments/s]
# Aligning 9J25DZhivz8:  35%|█████████████████▋                                | 196/554 [00:00<00:00, 483.28 Segments/s]
/ Computational Sequence Entries]
#   0%|                                                                                   | 0/676 [00:00<?, ? Segments/s]
# Aligning zhpQhgha_KU:   0%|                                                             | 0/676 [00:00<?, ? Segments/s]
# Aligning zhpQhgha_KU:   6%|██▊                                                | 38/676 [00:00<00:01, 378.05 Segments/s]
# Aligning zhpQhgha_KU:  12%|█████▉                                             | 78/676 [00:00<00:01, 388.76 Segments/s]
# Aligning zhpQhgha_KU:  19%|█████████▎                                        | 126/676 [00:00<00:01, 429.65 Segments/s]
# Aligning zhpQhgha_KU:  25%|████████████▌                                     | 169/676 [00:00<00:01, 424.63 Segments/s]
# Aligning zhpQhgha_KU:  31%|███████████████▋                                  | 212/676 [00:00<00:01, 421.40 Segments/s]
# Aligning zhpQhgha_KU:  38%|██████████████████▊                               | 255/676 [00:00<00:01, 411.34 Segments/s]
# Aligning zhpQhgha_KU:  45%|██████████████████████▎                           | 301/676 [00:00<00:00, 424.39 Segments/s]
# Aligning zhpQhgha_KU:  51%|█████████████████████████▌                        | 346/676 [00:00<00:00, 431.87 Segments/s]
# Aligning zhpQhgha_KU:  58%|████████████████████████████▉                     | 392/676 [00:00<00:00, 436.83 Segments/s]
# Aligning zhpQhgha_KU:  64%|████████████████████████████████▏                 | 436/676 [00:01<00:00, 430.37 Segments/s]
# Aligning zhpQhgha_KU:  71%|███████████████████████████████████▋              | 483/676 [00:01<00:00, 438.63 Segments/s]
# Aligning zhpQhgha_KU:  78%|██████████████████████████████████████▉           | 527/676 [00:01<00:00, 438.49 Segments/s]
# Aligning zhpQhgha_KU:  85%|██████████████████████████████████████████▍       | 574/676 [00:01<00:00, 445.63 Segments/s]
# Aligning zhpQhgha_KU:  92%|█████████████████████████████████████████████▊    | 619/676 [00:01<00:00, 444.60 Segments/s]
# Aligning zhpQhgha_KU:  98%|█████████████████████████████████████████████████ | 664/676 [00:01<00:00, 444.80 Segments/s]
# [2024-04-10 10:07:53.737] | Success | Alignment to <CMU_MOSI_TimestampedWordVectors> complete.
# [2024-04-10 10:07:53.737] | Status  | Replacing dataset content with aligned computational sequences
# [2024-04-10 10:07:53.745] | Success | Initialized empty <CMU_MOSI_TimestampedWordVectors> computational sequence.
# [2024-04-10 10:07:53.745] | Status  | Checking the format of the data in <CMU_MOSI_TimestampedWordVectors> computational sequence ...
# [2024-04-10 10:07:53.844] | Success | <CMU_MOSI_TimestampedWordVectors> computational sequence data in correct format.
# [2024-04-10 10:07:53.844] | Status  | Checking the format of the metadata in <CMU_MOSI_TimestampedWordVectors> computational sequence ...
# [2024-04-10 10:07:53.844] | Warning | <CMU_MOSI_TimestampedWordVectors> computational sequence does not have all the required metadata ... continuing
# [2024-04-10 10:07:53.844] | Success | Initialized empty <CMU_MOSI_Visual_Facet_41> computational sequence.
# [2024-04-10 10:07:53.844] | Status  | Checking the format of the data in <CMU_MOSI_Visual_Facet_41> computational sequence ...
# [2024-04-10 10:07:53.930] | Success | <CMU_MOSI_Visual_Facet_41> computational sequence data in correct format.
# [2024-04-10 10:07:53.930] | Status  | Checking the format of the metadata in <CMU_MOSI_Visual_Facet_41> computational sequence ...
# [2024-04-10 10:07:53.930] | Warning | <CMU_MOSI_Visual_Facet_41> computational sequence does not have all the required metadata ... continuing
# [2024-04-10 10:07:53.930] | Success | Initialized empty <CMU_MOSI_COVAREP> computational sequence.
# [2024-04-10 10:07:53.930] | Status  | Checking the format of the data in <CMU_MOSI_COVAREP> computational sequence ...
# [2024-04-10 10:07:54.016] | Success | <CMU_MOSI_COVAREP> computational sequence data in correct format.
# [2024-04-10 10:07:54.016] | Status  | Checking the format of the metadata in <CMU_MOSI_COVAREP> computational sequence ...
# [2024-04-10 10:07:54.016] | Warning | <CMU_MOSI_COVAREP> computational sequence does not have all the required metadata ... continuing

# %%
label_field = 'CMU_MOSI_Opinion_Labels'
label_recipe = {label_field: os.path.join('C:/Users/Administrator/PycharmProjects/demo1/cmu_mosi_labels/', label_field + '.csd')}
dataset.add_computational_sequences(label_recipe, destination=None)
dataset.align(label_field, replace=True)
# Out:
# [2024-04-10 11:05:55.333] | Warning | Dataset already contains <CMU_MOSI_Opinion_Labels> computational sequence ...
# [2024-04-10 11:05:55.341] | Success | Computational sequence read from file C:/Users/Administrator/PycharmProjects/demo1/cmu_mosi_labels/CMU_MOSI_Opinion_Labels.csd ...
# [2024-04-10 11:05:55.362] | Status  | Checking the integrity of the <Opinion Segment Labels> computational sequence ...
# [2024-04-10 11:05:55.362] | Status  | Checking the format of the data in <Opinion Segment Labels> computational sequence ...
# [2024-04-10 11:05:55.415] | Success | <Opinion Segment Labels> computational sequence data in correct format.
# [2024-04-10 11:05:55.415] | Status  | Checking the format of the metadata in <Opinion Segment Labels> computational sequence ...
# [2024-04-10 11:05:55.415] | Warning | <Opinion Segment Labels> computational sequence does not have all the required metadata ... continuing
# [2024-04-10 11:05:55.425] | Status  | Unify was called ...
# [2024-04-10 11:05:55.432] | Success | Unify completed ...
# [2024-04-10 11:05:55.432] | Status  | Pre-alignment based on <CMU_MOSI_Opinion_Labels> computational sequence started ...
# [2024-04-10 11:05:55.477] | Status  | Pre-alignment done for <CMU_MOSI_Visual_Facet_41> ...
# [2024-04-10 11:05:55.512] | Status  | Pre-alignment done for <CMU_MOSI_COVAREP> ...
# [2024-04-10 11:05:55.622] | Status  | Pre-alignment done for <CMU_MOSI_TimestampedWordVectors> ...
# [2024-04-10 11:05:55.623] | Status  | Alignment starting ...
# Overall Progress:   0%|                                            | 0/93 [00:00<?, ? Computational Sequence Entries/s]
#   0%|                                                                                    | 0/13 [00:00<?, ? Segments/s]
# Aligning 03bSnISJMiM:   0%|                                                              | 0/13 [00:00<?, ? Segments/s]
#
#   0%|                                                                                    | 0/25 [00:00<?, ? Segments/s]
# Aligning 0h-zjBukYpk:   0%|                                                              | 0/25 [00:00<?, ? Segments/s]
#
#   0%|                                                                                    | 0/14 [00:00<?, ? Segments/s]
# Aligning 1DmNV9C1hbY:   0%|                                                              | 0/14 [00:00<?, ? Segments/s]
#
#   0%|                                                                                    | 0/30 [00:00<?, ? Segments/s]
# Aligning 1iG0909rllw:   0%|                                                              | 0/30 [00:00<?, ? Segments/s]
# Overall Progress:   4%|█▌                                  | 4/93 [00:00<00:02, 33.83 Computational Sequence Entries/s]
#   0%|                                                                                    | 0/63 [00:00<?, ? Segments/s]
# Aligning 2WGyTLYerpo:   0%|                                                              | 0/63 [00:00<?, ? Segments/s]
#
#   0%|                                                                                    | 0/30 [00:00<?, ? Segments/s]
# Aligning 2iD-tVS8NPw:   0%|                                                              | 0/30 [00:00<?, ? Segments/s]
#
#   0%|                                                                                    | 0/24 [00:00<?, ? Segments/s]
# Aligning 5W7Z1C_fDaE:   0%|                                                              | 0/24 [00:00<?, ? Segments/s]
#
#   0%|                                                                                    | 0/12 [00:00<?, ? Segments/s]
# Aligning 6Egk_28TtTM:   0%|                                                              | 0/12 [00:00<?, ? Segments/s]
# Overall Progress:   9%|███                                 | 8/93 [00:00<00:02, 31.49 Computational Sequence Entries/s]
#   0%|                                                                                    | 0/14 [00:00<?, ? Segments/s]
# Aligning 6_0THN4chvY:   0%|                                                              | 0/14 [00:00<?, ? Segments/s]
#
#   0%|                                                                                    | 0/19 [00:00<?, ? Segments/s]
# Aligning 73jzhE8R1TQ:   0%|                                                              | 0/19 [00:00<?, ? Segments/s]
#
#   0%|                                                                                    | 0/39 [00:00<?, ? Segments/s]
# Aligning 7JsX8y1ysxY:   0%|                                                              | 0/39 [00:00<?, ? Segments/s]
#
#   0%|                                                                                    | 0/23 [00:00<?, ? Segments/s]
# Aligning 8OtFthrtaJM:   0%|                                                              | 0/23 [00:00<?, ? Segments/s]
# Overall Progress:  13%|████▌                              | 12/93 [00:00<00:02, 33.33 Computational Sequence Entries/s]
#   0%|                                                                                    | 0/30 [00:00<?, ? Segments/s]
# Aligning 8d-gEyoeBzc:   0%|                                                              | 0/30 [00:00<?, ? Segments/s]
#
#   0%|                                                                                    | 0/26 [00:00<?, ? Segments/s]
# Aligning 8qrpnFRGt2A:   0%|                                                              | 0/26 [00:00<?, ? Segments/s]
#
#   0%|                                                                                    | 0/25 [00:00<?, ? Segments/s]
# Aligning 9J25DZhivz8:   0%|                                                              | 0/25 [00:00<?, ? Segments/s]
#
#   0%|                                                                                    | 0/25 [00:00<?, ? Segments/s]
# Aligning 9T9Hf74oK10:   0%|                                                              | 0/25 [00:00<?, ? Segments/s]
# Overall Progress:  17%|██████                             | 16/93 [00:00<00:02, 33.81 Computational Sequence Entries/s]
#   0%|                                                                                    | 0/12 [00:00<?, ? Segments/s]
# Aligning 9c67fiY0wGQ:   0%|                                                              | 0/12 [00:00<?, ? Segments/s]
#
#   0%|                                                                                    | 0/33 [00:00<?, ? Segments/s]
# Aligning 9qR7uwkblbs:   0%|                                                              | 0/33 [00:00<?, ? Segments/s]
#
#   0%|                                                                                    | 0/31 [00:00<?, ? Segments/s]
# Aligning Af8D0E4ZXaw:   0%|                                                              | 0/31 [00:00<?, ? Segments/s]
#
#   0%|                                                                                    | 0/31 [00:00<?, ? Segments/s]
# Aligning BI97DNYfe5I:   0%|                                                              | 0/31 [00:00<?, ? Segments/s]
# Overall Progress:  22%|███████▌                           | 20/93 [00:00<00:02, 34.50 Computational Sequence Entries/s]
#   0%|                                                                                    | 0/31 [00:00<?, ? Segments/s]
# Aligning BXuRRbG0Ugk:   0%|                                                              | 0/31 [00:00<?, ? Segments/s]
#
#   0%|                                                                                    | 0/22 [00:00<?, ? Segments/s]
# Aligning Bfr499ggo-0:   0%|                                                              | 0/22 [00:00<?, ? Segments/s]
#
#   0%|                                                                                    | 0/30 [00:00<?, ? Segments/s]
# Aligning BioHAh1qJAQ:   0%|                                                              | 0/30 [00:00<?, ? Segments/s]
#
#   0%|                                                                                    | 0/26 [00:00<?, ? Segments/s]
# Aligning BvYR0L6f2Ig:   0%|                                                              | 0/26 [00:00<?, ? Segments/s]
# Overall Progress:  26%|█████████                          | 24/93 [00:00<00:02, 34.03 Computational Sequence Entries/s]
#   0%|                                                                                    | 0/44 [00:00<?, ? Segments/s]
# Aligning Ci-AH39fi3Y:   0%|                                                              | 0/44 [00:00<?, ? Segments/s]
#
#   0%|                                                                                    | 0/31 [00:00<?, ? Segments/s]
# Aligning Clx4VXItLTE:   0%|                                                              | 0/31 [00:00<?, ? Segments/s]
#
#   0%|                                                                                    | 0/18 [00:00<?, ? Segments/s]
# Aligning Dg_0XKD0Mf4:   0%|                                                              | 0/18 [00:00<?, ? Segments/s]
#
#   0%|                                                                                    | 0/21 [00:00<?, ? Segments/s]
# Aligning G-xst2euQUc:   0%|                                                              | 0/21 [00:00<?, ? Segments/s]
# Overall Progress:  30%|██████████▌                        | 28/93 [00:00<00:01, 33.74 Computational Sequence Entries/s]
#   0%|                                                                                    | 0/29 [00:00<?, ? Segments/s]
# Aligning G6GlGvlkxAQ:   0%|                                                              | 0/29 [00:00<?, ? Segments/s]
#
#   0%|                                                                                    | 0/18 [00:00<?, ? Segments/s]
# Aligning GWuJjcEuzt8:   0%|                                                              | 0/18 [00:00<?, ? Segments/s]
#
#   0%|                                                                                    | 0/34 [00:00<?, ? Segments/s]
# Aligning HEsqda8_d0Q:   0%|                                                              | 0/34 [00:00<?, ? Segments/s]
#
#   0%|                                                                                    | 0/39 [00:00<?, ? Segments/s]
# Aligning I5y0__X72p0:   0%|                                                              | 0/39 [00:00<?, ? Segments/s]
# Overall Progress:  34%|████████████                       | 32/93 [00:00<00:01, 33.82 Computational Sequence Entries/s]
#   0%|                                                                                    | 0/16 [00:00<?, ? Segments/s]
# Aligning Iu2PFX3z_1s:   0%|                                                              | 0/16 [00:00<?, ? Segments/s]
#
#   0%|                                                                                    | 0/22 [00:00<?, ? Segments/s]
# Aligning IumbAb8q2dM:   0%|                                                              | 0/22 [00:00<?, ? Segments/s]
#
#   0%|                                                                                    | 0/20 [00:00<?, ? Segments/s]
# Aligning Jkswaaud0hk:   0%|                                                              | 0/20 [00:00<?, ? Segments/s]
#
#   0%|                                                                                    | 0/29 [00:00<?, ? Segments/s]
# Aligning LSi-o-IrDMs:   0%|                                                              | 0/29 [00:00<?, ? Segments/s]
#
#   0%|                                                                                    | 0/18 [00:00<?, ? Segments/s]
# Aligning MLal-t_vJPM:   0%|                                                              | 0/18 [00:00<?, ? Segments/s]
# Overall Progress:  40%|█████████████▉                     | 37/93 [00:01<00:01, 36.52 Computational Sequence Entries/s]
#   0%|                                                                                    | 0/13 [00:00<?, ? Segments/s]
# Aligning Njd1F0vZSm4:   0%|                                                              | 0/13 [00:00<?, ? Segments/s]
#
#   0%|                                                                                    | 0/32 [00:00<?, ? Segments/s]
# Aligning Nzq88NnDkEk:   0%|                                                              | 0/32 [00:00<?, ? Segments/s]
#
#   0%|                                                                                    | 0/16 [00:00<?, ? Segments/s]
# Aligning OQvJTdtJ2H4:   0%|                                                              | 0/16 [00:00<?, ? Segments/s]
#
#   0%|                                                                                    | 0/24 [00:00<?, ? Segments/s]
# Aligning OtBXNcAL_lE:   0%|                                                              | 0/24 [00:00<?, ? Segments/s]
#
#   0%|                                                                                    | 0/25 [00:00<?, ? Segments/s]
# Aligning Oz06ZWiO20M:   0%|                                                              | 0/25 [00:00<?, ? Segments/s]
# Overall Progress:  45%|███████████████▊                   | 42/93 [00:01<00:01, 38.50 Computational Sequence Entries/s]
#   0%|                                                                                    | 0/13 [00:00<?, ? Segments/s]
# Aligning POKffnXeBds:   0%|                                                              | 0/13 [00:00<?, ? Segments/s]
#
#   0%|                                                                                    | 0/12 [00:00<?, ? Segments/s]
# Aligning PZ-lDQFboO8:   0%|                                                              | 0/12 [00:00<?, ? Segments/s]
#
#   0%|                                                                                    | 0/18 [00:00<?, ? Segments/s]
# Aligning QN9ZIUWUXsY:   0%|                                                              | 0/18 [00:00<?, ? Segments/s]
#
#   0%|                                                                                    | 0/14 [00:00<?, ? Segments/s]
# Aligning Qr1Ca94K55A:   0%|                                                              | 0/14 [00:00<?, ? Segments/s]
#
#   0%|                                                                                    | 0/22 [00:00<?, ? Segments/s]
# Aligning Sqr0AcuoNnk:   0%|                                                              | 0/22 [00:00<?, ? Segments/s]
# Overall Progress:  51%|█████████████████▋                 | 47/93 [00:01<00:01, 41.11 Computational Sequence Entries/s]
#   0%|                                                                                    | 0/15 [00:00<?, ? Segments/s]
# Aligning TvyZBvOMOTc:   0%|                                                              | 0/15 [00:00<?, ? Segments/s]
#
#   0%|                                                                                    | 0/17 [00:00<?, ? Segments/s]
# Aligning VCslbP0mgZI:   0%|                                                              | 0/17 [00:00<?, ? Segments/s]
#
#   0%|                                                                                    | 0/55 [00:00<?, ? Segments/s]
# Aligning VbQk4H8hgr0:   0%|                                                              | 0/55 [00:00<?, ? Segments/s]
#
#   0%|                                                                                     | 0/9 [00:00<?, ? Segments/s]
# Aligning Vj1wYRQjB-o:   0%|                                                               | 0/9 [00:00<?, ? Segments/s]
#
#   0%|                                                                                    | 0/32 [00:00<?, ? Segments/s]
# Aligning W8NXH0Djyww:   0%|                                                              | 0/32 [00:00<?, ? Segments/s]
# Overall Progress:  56%|███████████████████▌               | 52/93 [00:01<00:01, 38.11 Computational Sequence Entries/s]
#   0%|                                                                                    | 0/22 [00:00<?, ? Segments/s]
# Aligning WKA5OygbEKI:   0%|                                                              | 0/22 [00:00<?, ? Segments/s]
#
#   0%|                                                                                    | 0/11 [00:00<?, ? Segments/s]
# Aligning X3j2zQgwYgE:   0%|                                                              | 0/11 [00:00<?, ? Segments/s]
#
#   0%|                                                                                     | 0/9 [00:00<?, ? Segments/s]
# Aligning ZAIRrfG22O0:   0%|                                                               | 0/9 [00:00<?, ? Segments/s]
#
#   0%|                                                                                    | 0/34 [00:00<?, ? Segments/s]
# Aligning ZUXBRvtny7o:   0%|                                                              | 0/34 [00:00<?, ? Segments/s]
# Overall Progress:  60%|█████████████████████              | 56/93 [00:01<00:00, 37.28 Computational Sequence Entries/s]
#   0%|                                                                                    | 0/28 [00:00<?, ? Segments/s]
# Aligning _dI--eQ6qVU:   0%|                                                              | 0/28 [00:00<?, ? Segments/s]
#
#   0%|                                                                                    | 0/30 [00:00<?, ? Segments/s]
# Aligning aiEXnCPZubE:   0%|                                                              | 0/30 [00:00<?, ? Segments/s]
#
#   0%|                                                                                    | 0/21 [00:00<?, ? Segments/s]
# Aligning atnd_PF-Lbs:   0%|                                                              | 0/21 [00:00<?, ? Segments/s]
#
#   0%|                                                                                    | 0/34 [00:00<?, ? Segments/s]
# Aligning bOL9jKpeJRs:   0%|                                                              | 0/34 [00:00<?, ? Segments/s]
# Overall Progress:  65%|██████████████████████▌            | 60/93 [00:01<00:00, 36.68 Computational Sequence Entries/s]
#   0%|                                                                                    | 0/25 [00:00<?, ? Segments/s]
# Aligning bvLlb-M3UXU:   0%|                                                              | 0/25 [00:00<?, ? Segments/s]
#
#   0%|                                                                                    | 0/15 [00:00<?, ? Segments/s]
# Aligning c5xsKMxpXnc:   0%|                                                              | 0/15 [00:00<?, ? Segments/s]
#
#   0%|                                                                                    | 0/33 [00:00<?, ? Segments/s]
# Aligning c7UH_rxdZv4:   0%|                                                              | 0/33 [00:00<?, ? Segments/s]
#
#   0%|                                                                                    | 0/16 [00:00<?, ? Segments/s]
# Aligning cM3Yna7AavY:   0%|                                                              | 0/16 [00:00<?, ? Segments/s]
# Overall Progress:  69%|████████████████████████           | 64/93 [00:01<00:00, 37.19 Computational Sequence Entries/s]
#   0%|                                                                                    | 0/24 [00:00<?, ? Segments/s]
# Aligning cW1FSBF59ik:   0%|                                                              | 0/24 [00:00<?, ? Segments/s]
#
#   0%|                                                                                    | 0/29 [00:00<?, ? Segments/s]
# Aligning cXypl4FnoZo:   0%|                                                              | 0/29 [00:00<?, ? Segments/s]
#
#   0%|                                                                                    | 0/19 [00:00<?, ? Segments/s]
# Aligning d3_k5Xpfmik:   0%|                                                              | 0/19 [00:00<?, ? Segments/s]
#
#   0%|                                                                                    | 0/43 [00:00<?, ? Segments/s]
# Aligning d6hH302o4v8:   0%|                                                              | 0/43 [00:00<?, ? Segments/s]
# Overall Progress:  73%|█████████████████████████▌         | 68/93 [00:01<00:00, 34.59 Computational Sequence Entries/s]
#   0%|                                                                                    | 0/15 [00:00<?, ? Segments/s]
# Aligning dq3Nf_lMPnE:   0%|                                                              | 0/15 [00:00<?, ? Segments/s]
#
#   0%|                                                                                    | 0/19 [00:00<?, ? Segments/s]
# Aligning etzxEpPuc6I:   0%|                                                              | 0/19 [00:00<?, ? Segments/s]
#
#   0%|                                                                                    | 0/30 [00:00<?, ? Segments/s]
# Aligning f9O3YtZ2VfI:   0%|                                                              | 0/30 [00:00<?, ? Segments/s]
#
#   0%|                                                                                    | 0/15 [00:00<?, ? Segments/s]
# Aligning f_pcplsH_V0:   0%|                                                              | 0/15 [00:00<?, ? Segments/s]
#
#   0%|                                                                                    | 0/14 [00:00<?, ? Segments/s]
# Aligning fvVhgmXxadc:   0%|                                                              | 0/14 [00:00<?, ? Segments/s]
# Overall Progress:  78%|███████████████████████████▍       | 73/93 [00:02<00:00, 37.43 Computational Sequence Entries/s]
#   0%|                                                                                    | 0/18 [00:00<?, ? Segments/s]
# Aligning iiK8YX8oH1E:   0%|                                                              | 0/18 [00:00<?, ? Segments/s]
#
#   0%|                                                                                    | 0/27 [00:00<?, ? Segments/s]
# Aligning jUzDDGyPkXU:   0%|                                                              | 0/27 [00:00<?, ? Segments/s]
#
#   0%|                                                                                    | 0/31 [00:00<?, ? Segments/s]
# Aligning k5Y_838nuGo:   0%|                                                              | 0/31 [00:00<?, ? Segments/s]
#
#   0%|                                                                                    | 0/30 [00:00<?, ? Segments/s]
# Aligning lXPQBPVc5Cw:   0%|                                                              | 0/30 [00:00<?, ? Segments/s]
# Overall Progress:  83%|████████████████████████████▉      | 77/93 [00:02<00:00, 35.70 Computational Sequence Entries/s]
#   0%|                                                                                    | 0/10 [00:00<?, ? Segments/s]
# Aligning nbWiPyCm4g0:   0%|                                                              | 0/10 [00:00<?, ? Segments/s]
#
#   0%|                                                                                    | 0/24 [00:00<?, ? Segments/s]
# Aligning nzpVDcQ0ywM:   0%|                                                              | 0/24 [00:00<?, ? Segments/s]
#
#   0%|                                                                                    | 0/14 [00:00<?, ? Segments/s]
# Aligning ob23OKe5a9Q:   0%|                                                              | 0/14 [00:00<?, ? Segments/s]
#
#   0%|                                                                                    | 0/16 [00:00<?, ? Segments/s]
# Aligning pLTX3ipuDJI:   0%|                                                              | 0/16 [00:00<?, ? Segments/s]
#
#   0%|                                                                                    | 0/21 [00:00<?, ? Segments/s]
# Aligning phBUpBr1hSo:   0%|                                                              | 0/21 [00:00<?, ? Segments/s]
# Overall Progress:  88%|██████████████████████████████▊    | 82/93 [00:02<00:00, 39.07 Computational Sequence Entries/s]
#   0%|                                                                                    | 0/22 [00:00<?, ? Segments/s]
# Aligning rnaNMUZpvvg:   0%|                                                              | 0/22 [00:00<?, ? Segments/s]
#
#   0%|                                                                                    | 0/18 [00:00<?, ? Segments/s]
# Aligning tIrG4oNLFzE:   0%|                                                              | 0/18 [00:00<?, ? Segments/s]
#
#   0%|                                                                                    | 0/16 [00:00<?, ? Segments/s]
# Aligning tStelxIAHjw:   0%|                                                              | 0/16 [00:00<?, ? Segments/s]
#
#   0%|                                                                                    | 0/20 [00:00<?, ? Segments/s]
# Aligning tmZoasNr4rU:   0%|                                                              | 0/20 [00:00<?, ? Segments/s]
#
#   0%|                                                                                    | 0/16 [00:00<?, ? Segments/s]
# Aligning v0zCBqDeKcE:   0%|                                                              | 0/16 [00:00<?, ? Segments/s]
# Overall Progress:  94%|████████████████████████████████▋  | 87/93 [00:02<00:00, 41.50 Computational Sequence Entries/s]
#   0%|                                                                                    | 0/12 [00:00<?, ? Segments/s]
# Aligning vvZ4IcEtiZc:   0%|                                                              | 0/12 [00:00<?, ? Segments/s]
#
#   0%|                                                                                    | 0/22 [00:00<?, ? Segments/s]
# Aligning vyB00TXsimI:   0%|                                                              | 0/22 [00:00<?, ? Segments/s]
#
#   0%|                                                                                    | 0/30 [00:00<?, ? Segments/s]
# Aligning wMbj6ajWbic:   0%|                                                              | 0/30 [00:00<?, ? Segments/s]
#
#   0%|                                                                                    | 0/24 [00:00<?, ? Segments/s]
# Aligning yDtzw_Y-7RU:   0%|                                                              | 0/24 [00:00<?, ? Segments/s]
#
#   0%|                                                                                    | 0/23 [00:00<?, ? Segments/s]
# Aligning yvsjCA6Y5Fc:   0%|                                                              | 0/23 [00:00<?, ? Segments/s]
# Overall Progress:  99%|██████████████████████████████████▌| 92/93 [00:02<00:00, 40.43 Computational Sequence Entries/s]
#   0%|                                                                                    | 0/35 [00:00<?, ? Segments/s]
# Aligning zhpQhgha_KU:   0%|                                                              | 0/35 [00:00<?, ? Segments/s]
# [2024-04-10 11:05:58.143] | Success | Alignment to <CMU_MOSI_Opinion_Labels> complete.
# [2024-04-10 11:05:58.143] | Status  | Replacing dataset content with aligned computational sequences
# [2024-04-10 11:05:58.149] | Success | Initialized empty <CMU_MOSI_TimestampedWordVectors> computational sequence.
# [2024-04-10 11:05:58.149] | Status  | Checking the format of the data in <CMU_MOSI_TimestampedWordVectors> computational sequence ...
# [2024-04-10 11:05:58.154] | Success | <CMU_MOSI_TimestampedWordVectors> computational sequence data in correct format.
# [2024-04-10 11:05:58.154] | Status  | Checking the format of the metadata in <CMU_MOSI_TimestampedWordVectors> computational sequence ...
# [2024-04-10 11:05:58.154] | Warning | <CMU_MOSI_TimestampedWordVectors> computational sequence does not have all the required metadata ... continuing
# [2024-04-10 11:05:58.154] | Success | Initialized empty <CMU_MOSI_Visual_Facet_41> computational sequence.
# [2024-04-10 11:05:58.154] | Status  | Checking the format of the data in <CMU_MOSI_Visual_Facet_41> computational sequence ...
# [2024-04-10 11:05:58.161] | Success | <CMU_MOSI_Visual_Facet_41> computational sequence data in correct format.
# [2024-04-10 11:05:58.161] | Status  | Checking the format of the metadata in <CMU_MOSI_Visual_Facet_41> computational sequence ...
# [2024-04-10 11:05:58.161] | Warning | <CMU_MOSI_Visual_Facet_41> computational sequence does not have all the required metadata ... continuing
# [2024-04-10 11:05:58.161] | Success | Initialized empty <CMU_MOSI_COVAREP> computational sequence.
# [2024-04-10 11:05:58.161] | Status  | Checking the format of the data in <CMU_MOSI_COVAREP> computational sequence ...
# [2024-04-10 11:05:58.167] | Success | <CMU_MOSI_COVAREP> computational sequence data in correct format.
# [2024-04-10 11:05:58.167] | Status  | Checking the format of the metadata in <CMU_MOSI_COVAREP> computational sequence ...
# [2024-04-10 11:05:58.167] | Warning | <CMU_MOSI_COVAREP> computational sequence does not have all the required metadata ... continuing
# [2024-04-10 11:05:58.167] | Success | Initialized empty <CMU_MOSI_Opinion_Labels> computational sequence.
# [2024-04-10 11:05:58.167] | Status  | Checking the format of the data in <CMU_MOSI_Opinion_Labels> computational sequence ...
# [2024-04-10 11:05:58.175] | Success | <CMU_MOSI_Opinion_Labels> computational sequence data in correct format.
# [2024-04-10 11:05:58.176] | Status  | Checking the format of the metadata in <CMU_MOSI_Opinion_Labels> computational sequence ...
# [2024-04-10 11:05:58.176] | Warning | <CMU_MOSI_Opinion_Labels> computational sequence does not have all the required metadata ... continuing

# %%
deploy_files={x:x for x in dataset.computational_sequences.keys()}
dataset.deploy("C:/Users/Administrator/PycharmProjects/demo1/deployed/",deploy_files)
aligned_cmumosi_highlevel=md.mmdataset('C:/Users/Administrator/PycharmProjects/demo1/deployed/')
# Out:
# [2024-04-10 11:10:55.262] | Status  | Checking the integrity of the <glove_vectors> computational sequence ...
# [2024-04-10 11:10:55.262] | Status  | Checking the format of the data in <glove_vectors> computational sequence ...
# [2024-04-10 11:10:55.272] | Success | <glove_vectors> computational sequence data in correct format.
# [2024-04-10 11:10:55.272] | Status  | Checking the format of the metadata in <glove_vectors> computational sequence ...
# [2024-04-10 11:10:55.272] | Success | <glove_vectors> computational sequence metadata in correct format.
# [2024-04-10 11:10:55.272] | Success | <glove_vectors> computational sequence is valid!
# [2024-04-10 11:10:55.272] | Status  | Deploying the <C:/Users/Administrator/PycharmProjects/demo1/deployed/CMU_MOSI_TimestampedWordVectors.csd> computational sequence to glove_vectors
# [2024-04-10 11:10:55.272] | Status  | Your unique identifier for <glove_vectors> computational sequence is bf55753e-37af-4051-b972-b6a6bfffb6a4
# [2024-04-10 11:10:55.272] | Status  | Writing the <glove_vectors> computational sequence data to C:/Users/Administrator/PycharmProjects/demo1/deployed/CMU_MOSI_TimestampedWordVectors.csd
# [2024-04-10 11:10:55.272] | Advise  | Compression with gzip and opts -9
# [2024-04-10 11:10:58.299] | Success | <glove_vectors> computational sequence data successfully wrote to C:/Users/Administrator/PycharmProjects/demo1/deployed/CMU_MOSI_TimestampedWordVectors.csd
# [2024-04-10 11:10:58.299] | Status  | Writing the <glove_vectors> computational sequence metadata to C:/Users/Administrator/PycharmProjects/demo1/deployed/CMU_MOSI_TimestampedWordVectors.csd
# [2024-04-10 11:10:58.313] | Success | <glove_vectors> computational sequence metadata successfully wrote to C:/Users/Administrator/PycharmProjects/demo1/deployed/CMU_MOSI_TimestampedWordVectors.csd
# [2024-04-10 11:10:58.313] | Success | <glove_vectors> computational sequence successfully wrote to C:/Users/Administrator/PycharmProjects/demo1/deployed/CMU_MOSI_TimestampedWordVectors.csd ...
# [2024-04-10 11:10:58.313] | Status  | Checking the integrity of the <FACET_4.1> computational sequence ...
# [2024-04-10 11:10:58.313] | Status  | Checking the format of the data in <FACET_4.1> computational sequence ...
# [2024-04-10 11:10:58.319] | Success | <FACET_4.1> computational sequence data in correct format.
# [2024-04-10 11:10:58.320] | Status  | Checking the format of the metadata in <FACET_4.1> computational sequence ...
# [2024-04-10 11:10:58.320] | Success | <FACET_4.1> computational sequence metadata in correct format.
# [2024-04-10 11:10:58.320] | Success | <FACET_4.1> computational sequence is valid!
# [2024-04-10 11:10:58.320] | Status  | Deploying the <C:/Users/Administrator/PycharmProjects/demo1/deployed/CMU_MOSI_Visual_Facet_41.csd> computational sequence to FACET_4.1
# [2024-04-10 11:10:58.320] | Status  | Your unique identifier for <FACET_4.1> computational sequence is fd179a2b-13ff-49d6-b828-45483c6d6c0f
# [2024-04-10 11:10:58.320] | Status  | Writing the <FACET_4.1> computational sequence data to C:/Users/Administrator/PycharmProjects/demo1/deployed/CMU_MOSI_Visual_Facet_41.csd
# [2024-04-10 11:10:58.320] | Advise  | Compression with gzip and opts -9
# [2024-04-10 11:10:59.587] | Success | <FACET_4.1> computational sequence data successfully wrote to C:/Users/Administrator/PycharmProjects/demo1/deployed/CMU_MOSI_Visual_Facet_41.csd
# [2024-04-10 11:10:59.587] | Status  | Writing the <FACET_4.1> computational sequence metadata to C:/Users/Administrator/PycharmProjects/demo1/deployed/CMU_MOSI_Visual_Facet_41.csd
# [2024-04-10 11:10:59.601] | Success | <FACET_4.1> computational sequence metadata successfully wrote to C:/Users/Administrator/PycharmProjects/demo1/deployed/CMU_MOSI_Visual_Facet_41.csd
# [2024-04-10 11:10:59.601] | Success | <FACET_4.1> computational sequence successfully wrote to C:/Users/Administrator/PycharmProjects/demo1/deployed/CMU_MOSI_Visual_Facet_41.csd ...
# [2024-04-10 11:10:59.601] | Status  | Checking the integrity of the <COVAREP> computational sequence ...
# [2024-04-10 11:10:59.601] | Status  | Checking the format of the data in <COVAREP> computational sequence ...
# [2024-04-10 11:10:59.609] | Success | <COVAREP> computational sequence data in correct format.
# [2024-04-10 11:10:59.610] | Status  | Checking the format of the metadata in <COVAREP> computational sequence ...
# [2024-04-10 11:10:59.610] | Success | <COVAREP> computational sequence metadata in correct format.
# [2024-04-10 11:10:59.610] | Success | <COVAREP> computational sequence is valid!
# [2024-04-10 11:10:59.610] | Status  | Deploying the <C:/Users/Administrator/PycharmProjects/demo1/deployed/CMU_MOSI_COVAREP.csd> computational sequence to COVAREP
# [2024-04-10 11:10:59.610] | Status  | Your unique identifier for <COVAREP> computational sequence is e96b7f15-0809-47cf-a8df-6dc17d5f3437
# [2024-04-10 11:10:59.610] | Status  | Writing the <COVAREP> computational sequence data to C:/Users/Administrator/PycharmProjects/demo1/deployed/CMU_MOSI_COVAREP.csd
# [2024-04-10 11:10:59.610] | Advise  | Compression with gzip and opts -9
# [2024-04-10 11:11:00.980] | Success | <COVAREP> computational sequence data successfully wrote to C:/Users/Administrator/PycharmProjects/demo1/deployed/CMU_MOSI_COVAREP.csd
# [2024-04-10 11:11:00.980] | Status  | Writing the <COVAREP> computational sequence metadata to C:/Users/Administrator/PycharmProjects/demo1/deployed/CMU_MOSI_COVAREP.csd
# [2024-04-10 11:11:00.995] | Success | <COVAREP> computational sequence metadata successfully wrote to C:/Users/Administrator/PycharmProjects/demo1/deployed/CMU_MOSI_COVAREP.csd
# [2024-04-10 11:11:00.995] | Success | <COVAREP> computational sequence successfully wrote to C:/Users/Administrator/PycharmProjects/demo1/deployed/CMU_MOSI_COVAREP.csd ...
# [2024-04-10 11:11:00.995] | Status  | Checking the integrity of the <Opinion Segment Labels> computational sequence ...
# [2024-04-10 11:11:00.995] | Status  | Checking the format of the data in <Opinion Segment Labels> computational sequence ...
# [2024-04-10 11:11:01.002] | Success | <Opinion Segment Labels> computational sequence data in correct format.
# [2024-04-10 11:11:01.002] | Status  | Checking the format of the metadata in <Opinion Segment Labels> computational sequence ...
# [2024-04-10 11:11:01.002] | Success | <Opinion Segment Labels> computational sequence metadata in correct format.
# [2024-04-10 11:11:01.002] | Success | <Opinion Segment Labels> computational sequence is valid!
# [2024-04-10 11:11:01.002] | Status  | Deploying the <C:/Users/Administrator/PycharmProjects/demo1/deployed/CMU_MOSI_Opinion_Labels.csd> computational sequence to Opinion Segment Labels
# [2024-04-10 11:11:01.002] | Status  | Your unique identifier for <Opinion Segment Labels> computational sequence is 1ecfa31c-5c51-493b-ae0c-18f0dc47fcbb
# [2024-04-10 11:11:01.002] | Status  | Writing the <Opinion Segment Labels> computational sequence data to C:/Users/Administrator/PycharmProjects/demo1/deployed/CMU_MOSI_Opinion_Labels.csd
# [2024-04-10 11:11:01.002] | Advise  | Compression with gzip and opts -9
# [2024-04-10 11:11:01.950] | Success | <Opinion Segment Labels> computational sequence data successfully wrote to C:/Users/Administrator/PycharmProjects/demo1/deployed/CMU_MOSI_Opinion_Labels.csd
# [2024-04-10 11:11:01.950] | Status  | Writing the <Opinion Segment Labels> computational sequence metadata to C:/Users/Administrator/PycharmProjects/demo1/deployed/CMU_MOSI_Opinion_Labels.csd
# [2024-04-10 11:11:01.964] | Success | <Opinion Segment Labels> computational sequence metadata successfully wrote to C:/Users/Administrator/PycharmProjects/demo1/deployed/CMU_MOSI_Opinion_Labels.csd
# [2024-04-10 11:11:01.965] | Success | <Opinion Segment Labels> computational sequence successfully wrote to C:/Users/Administrator/PycharmProjects/demo1/deployed/CMU_MOSI_Opinion_Labels.csd ...
# [2024-04-10 11:11:01.965] | Success | Computational sequence read from file C:/Users/Administrator/PycharmProjects/demo1/deployed/CMU_MOSI_COVAREP.csd ...
# [2024-04-10 11:11:02.022] | Status  | Checking the integrity of the <COVAREP> computational sequence ...
# [2024-04-10 11:11:02.022] | Status  | Checking the format of the data in <COVAREP> computational sequence ...
# [2024-04-10 11:11:02.808] | Success | <COVAREP> computational sequence data in correct format.
# [2024-04-10 11:11:02.808] | Status  | Checking the format of the metadata in <COVAREP> computational sequence ...
# [2024-04-10 11:11:02.808] | Success | <COVAREP> computational sequence metadata in correct format.
# [2024-04-10 11:11:02.808] | Success | <COVAREP> computational sequence is valid!
# [2024-04-10 11:11:02.809] | Success | Computational sequence read from file C:/Users/Administrator/PycharmProjects/demo1/deployed/CMU_MOSI_Opinion_Labels.csd ...
# [2024-04-10 11:11:02.867] | Status  | Checking the integrity of the <Opinion Segment Labels> computational sequence ...
# [2024-04-10 11:11:02.867] | Status  | Checking the format of the data in <Opinion Segment Labels> computational sequence ...
# [2024-04-10 11:11:03.661] | Success | <Opinion Segment Labels> computational sequence data in correct format.
# [2024-04-10 11:11:03.661] | Status  | Checking the format of the metadata in <Opinion Segment Labels> computational sequence ...
# [2024-04-10 11:11:03.661] | Success | <Opinion Segment Labels> computational sequence metadata in correct format.
# [2024-04-10 11:11:03.661] | Success | <Opinion Segment Labels> computational sequence is valid!
# [2024-04-10 11:11:03.662] | Success | Computational sequence read from file C:/Users/Administrator/PycharmProjects/demo1/deployed/CMU_MOSI_TimestampedWordVectors.csd ...
# [2024-04-10 11:11:03.721] | Status  | Checking the integrity of the <glove_vectors> computational sequence ...
# [2024-04-10 11:11:03.722] | Status  | Checking the format of the data in <glove_vectors> computational sequence ...
# [2024-04-10 11:11:04.518] | Success | <glove_vectors> computational sequence data in correct format.
# [2024-04-10 11:11:04.518] | Status  | Checking the format of the metadata in <glove_vectors> computational sequence ...
# [2024-04-10 11:11:04.518] | Success | <glove_vectors> computational sequence metadata in correct format.
# [2024-04-10 11:11:04.518] | Success | <glove_vectors> computational sequence is valid!
# [2024-04-10 11:11:04.519] | Success | Computational sequence read from file C:/Users/Administrator/PycharmProjects/demo1/deployed/CMU_MOSI_Visual_Facet_41.csd ...
# [2024-04-10 11:11:04.584] | Status  | Checking the integrity of the <FACET_4.1> computational sequence ...
# [2024-04-10 11:11:04.584] | Status  | Checking the format of the data in <FACET_4.1> computational sequence ...
# [2024-04-10 11:11:05.357] | Success | <FACET_4.1> computational sequence data in correct format.
# [2024-04-10 11:11:05.357] | Status  | Checking the format of the metadata in <FACET_4.1> computational sequence ...
# [2024-04-10 11:11:05.357] | Success | <FACET_4.1> computational sequence metadata in correct format.
# [2024-04-10 11:11:05.357] | Success | <FACET_4.1> computational sequence is valid!
# [2024-04-10 11:11:05.357] | Success | Dataset initialized successfully ...

# %%
from mmsdk import mmdatasdk
import os, re
import numpy as np
from torch.utils.data import DataLoader
from collections import defaultdict
import torch
import torch.nn as nn
from tqdm import tqdm_notebook
from torch.optim import Adam, SGD
from sklearn.metrics import accuracy_score
import torch, os
from torch.nn.utils.rnn import pad_sequence, pack_padded_sequence, pad_packed_sequence
from torch.utils.data import DataLoader, Dataset
from tqdm import tqdm_notebook
 
word2id = defaultdict(lambda: len(word2id))
UNK = word2id['<unk>']
PAD = word2id['<pad>']
# def return_unk():
#     return UNK
# word2id.default_factory = return_unk
def splittraindevtest(train_split, dev_split, test_split, dataset, features):
    EPS = 0
    text_field, visual_field, acoustic_field, label_field = features
    # construct a word2id mapping that automatically takes increment when new words are encountered
    # place holders for the final train/dev/test dataset
    train = []
    dev = []
    test = []
    # define a regular expression to extract the video ID out of the keys
    pattern = re.compile('(.*)\[.*\]')
    num_drop = 0  # a counter to count how many data points went into some processing issues
    for segment in dataset[label_field].keys():
 
        # get the video ID and the features out of the aligned dataset
        vid = re.search(pattern, segment).group(1)
        label = dataset[label_field][segment]['features']
        _words = dataset[text_field][segment]['features']
        _visual = dataset[visual_field][segment]['features']
        _acoustic = dataset[acoustic_field][segment]['features']
 
        # if the sequences are not same length after alignment, there must be some problem with some modalities
        # we should drop it or inspect the data again
        if not _words.shape[0] == _visual.shape[0] == _acoustic.shape[0]:
            print(
                f"Encountered datapoint {vid} with text shape {_words.shape}, visual shape {_visual.shape}, acoustic shape {_acoustic.shape}")
            num_drop += 1
            continue
 
        # remove nan values
        label = np.nan_to_num(label)
        _visual = np.nan_to_num(_visual)
        _acoustic = np.nan_to_num(_acoustic)
 
        # remove speech pause tokens - this is in general helpful
        # we should remove speech pauses and corresponding visual/acoustic features together
        # otherwise modalities would no longer be aligned
        words = []
        visual = []
        acoustic = []
        for i, word in enumerate(_words):
            if word[0] != b'sp':
                words.append(word2id[word[0]])  # SDK stores strings as bytes, decode into strings here
                visual.append(_visual[i, :])
                acoustic.append(_acoustic[i, :])
 
        words = np.asarray(words)
        visual = np.asarray(visual)
        acoustic = np.asarray(acoustic)
 
        # z-normalization per instance and remove nan/infs
        visual = np.nan_to_num((visual - visual.mean(0, keepdims=True)) / (EPS + np.std(visual, axis=0, keepdims=True)))
        acoustic = np.nan_to_num(
            (acoustic - acoustic.mean(0, keepdims=True)) / (EPS + np.std(acoustic, axis=0, keepdims=True)))
 
        if vid in train_split:
            train.append(((words, visual, acoustic), label, segment))
        elif vid in dev_split:
            dev.append(((words, visual, acoustic), label, segment))
        elif vid in test_split:
            test.append(((words, visual, acoustic), label, segment))
        else:
            print(f"Found video that doesn't belong to any splits: {vid}")
 
    def return_unk():
        return UNK
 
    word2id.default_factory = return_unk
    print(f"Total number of {num_drop} datapoints have been dropped.")
    return train, dev, test
 
def multi_collate(batch):
    '''
    Collate functions assume batch = [Dataset[i] for i in index_set]
    '''
    # for later use we sort the batch in descending order of length
    batch = sorted(batch, key=lambda x: x[0][0].shape[0], reverse=True)
 
    # get the data out of the batch - use pad sequence util functions from PyTorch to pad things
    labels = torch.cat([torch.from_numpy(sample[1]) for sample in batch], dim=0)
    sentences = pad_sequence([torch.LongTensor(sample[0][0]) for sample in batch], padding_value=PAD)
    visual = pad_sequence([torch.FloatTensor(sample[0][1]) for sample in batch])
    acoustic = pad_sequence([torch.FloatTensor(sample[0][2]) for sample in batch])
 
    # lengths are useful later in using RNNs
    lengths = torch.LongTensor([sample[0][0].shape[0] for sample in batch])
    return sentences, visual, acoustic, labels, lengths
 
 
class LFLSTM(nn.Module):
    def __init__(self, input_sizes, hidden_sizes, fc1_size, output_size, dropout_rate):
        super(LFLSTM, self).__init__()
        self.input_size = input_sizes
        self.hidden_size = hidden_sizes
        self.fc1_size = fc1_size
        self.output_size = output_size
        self.dropout_rate = dropout_rate
 
        # defining modules - two layer bidirectional LSTM with layer norm in between
        self.embed = nn.Embedding(len(word2id), input_sizes[0])
        self.trnn1 = nn.LSTM(input_sizes[0], hidden_sizes[0], bidirectional=True)
        self.trnn2 = nn.LSTM(2 * hidden_sizes[0], hidden_sizes[0], bidirectional=True)
 
        self.vrnn1 = nn.LSTM(input_sizes[1], hidden_sizes[1], bidirectional=True)
        self.vrnn2 = nn.LSTM(2 * hidden_sizes[1], hidden_sizes[1], bidirectional=True)
 
        self.arnn1 = nn.LSTM(input_sizes[2], hidden_sizes[2], bidirectional=True)
        self.arnn2 = nn.LSTM(2 * hidden_sizes[2], hidden_sizes[2], bidirectional=True)
 
        self.fc1 = nn.Linear(sum(hidden_sizes) * 4, fc1_size)
        self.fc2 = nn.Linear(fc1_size, output_size)
        self.relu = nn.ReLU()
        self.dropout = nn.Dropout(dropout_rate)
        self.tlayer_norm = nn.LayerNorm((hidden_sizes[0] * 2,))
        self.vlayer_norm = nn.LayerNorm((hidden_sizes[1] * 2,))
        self.alayer_norm = nn.LayerNorm((hidden_sizes[2] * 2,))
        self.bn = nn.BatchNorm1d(sum(hidden_sizes) * 4)
 
    def extract_features(self, sequence, lengths, rnn1, rnn2, layer_norm):
        packed_sequence = pack_padded_sequence(sequence, lengths.cpu())
        packed_h1, (final_h1, _) = rnn1(packed_sequence)
        padded_h1, _ = pad_packed_sequence(packed_h1)
        normed_h1 = layer_norm(padded_h1)
        packed_normed_h1 = pack_padded_sequence(normed_h1, lengths.cpu())
        _, (final_h2, _) = rnn2(packed_normed_h1)
        return final_h1, final_h2
 
    def fusion(self, sentences, visual, acoustic, lengths):
        batch_size = lengths.size(0)
        sentences = self.embed(sentences)
 
        # extract features from text modality
        final_h1t, final_h2t = self.extract_features(sentences, lengths, self.trnn1, self.trnn2, self.tlayer_norm)
 
        # extract features from visual modality
        final_h1v, final_h2v = self.extract_features(visual, lengths, self.vrnn1, self.vrnn2, self.vlayer_norm)
 
        # extract features from acoustic modality
        final_h1a, final_h2a = self.extract_features(acoustic, lengths, self.arnn1, self.arnn2, self.alayer_norm)
 
        # simple late fusion -- concatenation + normalization
        h = torch.cat((final_h1t, final_h2t, final_h1v, final_h2v, final_h1a, final_h2a),
                      dim=2).permute(1, 0, 2).contiguous().view(batch_size, -1)
        return self.bn(h)
 
    def forward(self, sentences, visual, acoustic, lengths):
        batch_size = lengths.size(0)
        h = self.fusion(sentences, visual, acoustic, lengths)
        h = self.fc1(h)
        h = self.dropout(h)
        h = self.relu(h)
        o = self.fc2(h)
        return o
def load_emb(w2i, path_to_embedding, embedding_size=300, embedding_vocab=2196017, init_emb=None):
    if init_emb is None:
        emb_mat = np.random.randn(len(w2i), embedding_size)
    else:
        emb_mat = init_emb
    f = open(path_to_embedding, 'r')
    found = 0
    for line in tqdm_notebook(f, total=embedding_vocab):
        content = line.strip().split()
        vector = np.asarray(list(map(lambda x: float(x), content[-300:])))
        word = ' '.join(content[:-300])
        if word in w2i:
            idx = w2i[word]
            emb_mat[idx, :] = vector
            found += 1
    print(f"Found {found} words in the embedding file.")
    return torch.tensor(emb_mat).float()
def run(train_loader, dev_loader, test_loader):
    torch.manual_seed(123)
    torch.cuda.manual_seed_all(123)
 
    CUDA = True  # torch.cuda.is_available()
    MAX_EPOCH = 5
 
    text_size = 300
    visual_size = 47
    acoustic_size = 74
 
    # define some model settings and hyper-parameters
    input_sizes = [text_size, visual_size, acoustic_size]
    hidden_sizes = [int(text_size * 1.5), int(visual_size * 1.5), int(acoustic_size * 1.5)]
    fc1_size = sum(hidden_sizes) // 2
    dropout = 0.25
    output_size = 1
    curr_patience = patience = 8
    num_trials = 3
    grad_clip_value = 1.0
    weight_decay = 0.1
    CACHE_PATH = r'D:\Speech\jupyter_notes_zyx\CMU-MultimodalSDK-Tutorials-master\CMU-MultimodalSDK-Tutorials-master\data\embedding_and_mapping.pt'
    if os.path.exists(CACHE_PATH):
        pretrained_emb, word2id = torch.load(CACHE_PATH)
 
    else:
        pretrained_emb = None
 
    model = LFLSTM(input_sizes, hidden_sizes, fc1_size, output_size, dropout)
    if pretrained_emb is not None:
        model.embed.weight.data = pretrained_emb
    model.embed.requires_grad = False
    optimizer = Adam([param for param in model.parameters() if param.requires_grad], weight_decay=weight_decay)
 
    if CUDA:
        model.cuda()
    criterion = nn.L1Loss(reduction='sum')
    criterion_test = nn.L1Loss(reduction='sum')
    best_valid_loss = float('inf')
    lr_scheduler = torch.optim.lr_scheduler.StepLR(optimizer, step_size=1, gamma=0.1)
    lr_scheduler.step()  # for some reason it seems the StepLR needs to be stepped once first
    train_losses = []
    valid_losses = []
    for e in range(MAX_EPOCH):
        model.train()
        train_iter = tqdm_notebook(train_loader)
        train_loss = 0.0
        for batch in train_iter:
            model.zero_grad()
            t, v, a, y, l = batch
            batch_size = t.size(0)
            if CUDA:
                t = t.cuda()
                v = v.cuda()
                a = a.cuda()
                y = y.cuda()
                l = l.cuda()
            y_tilde = model(t, v, a, l)
            loss = criterion(y_tilde, y)
            loss.backward()
            torch.nn.utils.clip_grad_value_([param for param in model.parameters() if param.requires_grad], grad_clip_value)
            optimizer.step()
            train_iter.set_description(f"Epoch {e}/{MAX_EPOCH}, current batch loss: {round(loss.item() / batch_size, 4)}")
            train_loss += loss.item()
        train_loss = train_loss / len(train)
        train_losses.append(train_loss)
        print(f"Training loss: {round(train_loss, 4)}")
 
        model.eval()
        with torch.no_grad():
            valid_loss = 0.0
            for batch in dev_loader:
                model.zero_grad()
                t, v, a, y, l = batch
                if CUDA:
                    t = t.cuda()
                    v = v.cuda()
                    a = a.cuda()
                    y = y.cuda()
                    l = l.cuda()
                y_tilde = model(t, v, a, l)
                loss = criterion(y_tilde, y)
                valid_loss += loss.item()
 
        valid_loss = valid_loss / len(dev)
        valid_losses.append(valid_loss)
        print(f"Validation loss: {round(valid_loss, 4)}")
        print(f"Current patience: {curr_patience}, current trial: {num_trials}.")
        if valid_loss <= best_valid_loss:
            best_valid_loss = valid_loss
            print("Found new best model on dev set!")
            torch.save(model.state_dict(), 'model.std')
            torch.save(optimizer.state_dict(), 'optim.std')
            curr_patience = patience
        else:
            curr_patience -= 1
            if curr_patience <= -1:
                print("Running out of patience, loading previous best model.")
                num_trials -= 1
                curr_patience = patience
                model.load_state_dict(torch.load('model.std'))
                optimizer.load_state_dict(torch.load('optim.std'))
                lr_scheduler.step()
                print(f"Current learning rate: {optimizer.state_dict()['param_groups'][0]['lr']}")
 
        if num_trials <= 0:
            print("Running out of patience, early stopping.")
            break
 
    model.load_state_dict(torch.load('model.std'))
    y_true = []
    y_pred = []
    model.eval()
    with torch.no_grad():
        test_loss = 0.0
        for batch in test_loader:
            model.zero_grad()
            t, v, a, y, l = batch
            if CUDA:
                t = t.cuda()
                v = v.cuda()
                a = a.cuda()
                y = y.cuda()
                l = l.cuda()
            y_tilde = model(t, v, a, l)
            loss = criterion_test(y_tilde, y)
            y_true.append(y_tilde.detach().cpu().numpy())
            y_pred.append(y.detach().cpu().numpy())
            test_loss += loss.item()
    print(f"Test set performance: {test_loss / len(test)}")
    y_true = np.concatenate(y_true, axis=0)
    y_pred = np.concatenate(y_pred, axis=0)
 
    y_true_bin = y_true >= 0
    y_pred_bin = y_pred >= 0
    bin_acc = accuracy_score(y_true_bin, y_pred_bin)
    print(f"Test set accuracy is {bin_acc}")
 
if __name__=='__main__':
    visual_field1 = 'CMU_MOSI_Visual_Facet_41'
    acoustic_field1 = 'CMU_MOSI_COVAREP'
    text_field1 = 'CMU_MOSI_TimestampedWordVectors'
    label_field1 = 'CMU_MOSI_Opinion_Labels'
    features1 = [
        text_field1,
        visual_field1,
        acoustic_field1,
        label_field1
    ]
    DATA_PATH1 = 'C:/Users/Administrator/PycharmProjects/demo1/deployed'
    recipe1 = {feat: os.path.join(DATA_PATH1, feat) + '.csd' for feat in features1}
    dataset1 = mmdatasdk.mmdataset(recipe1)
    print(list(dataset1[text_field1].keys())[55])
    tensors = dataset1.get_tensors(seq_len=25, non_sequences=["Opinion Segment Labels"], direction=False,
                                   folds=[mmdatasdk.cmu_mosi.standard_folds.standard_train_fold, mmdatasdk.cmu_mosi.
                                   standard_folds.standard_valid_fold,
                                          mmdatasdk.cmu_mosi.standard_folds.standard_test_fold])
 
    fold_names = ["train", "valid", "test"]
    train, dev, test = splittraindevtest(mmdatasdk.cmu_mosi.standard_folds.standard_train_fold, mmdatasdk.cmu_mosi.
                                   standard_folds.standard_valid_fold, mmdatasdk.cmu_mosi.standard_folds.standard_test_fold,
                                         dataset1, features1)
 
    batch_sz = 56
    train_loader = DataLoader(train, shuffle=True, batch_size=batch_sz, collate_fn=multi_collate)
    dev_loader = DataLoader(dev, shuffle=False, batch_size=batch_sz * 3, collate_fn=multi_collate)
    test_loader = DataLoader(test, shuffle=False, batch_size=batch_sz * 3, collate_fn=multi_collate)
    run(train_loader, dev_loader, test_loader)
# Out:
# [2024-04-10 11:22:58.438] | Success | Computational sequence read from file C:/Users/Administrator/PycharmProjects/demo1/deployed\CMU_MOSI_TimestampedWordVectors.csd ...
# [2024-04-10 11:22:58.503] | Status  | Checking the integrity of the <glove_vectors> computational sequence ...
# [2024-04-10 11:22:58.503] | Status  | Checking the format of the data in <glove_vectors> computational sequence ...
# [2024-04-10 11:22:59.292] | Success | <glove_vectors> computational sequence data in correct format.
# [2024-04-10 11:22:59.292] | Status  | Checking the format of the metadata in <glove_vectors> computational sequence ...
# [2024-04-10 11:22:59.292] | Success | <glove_vectors> computational sequence metadata in correct format.
# [2024-04-10 11:22:59.292] | Success | <glove_vectors> computational sequence is valid!
# [2024-04-10 11:22:59.293] | Success | Computational sequence read from file C:/Users/Administrator/PycharmProjects/demo1/deployed\CMU_MOSI_Visual_Facet_41.csd ...
# [2024-04-10 11:22:59.350] | Status  | Checking the integrity of the <FACET_4.1> computational sequence ...
# [2024-04-10 11:22:59.350] | Status  | Checking the format of the data in <FACET_4.1> computational sequence ...
# [2024-04-10 11:23:00.122] | Success | <FACET_4.1> computational sequence data in correct format.
# [2024-04-10 11:23:00.122] | Status  | Checking the format of the metadata in <FACET_4.1> computational sequence ...
# [2024-04-10 11:23:00.122] | Success | <FACET_4.1> computational sequence metadata in correct format.
# [2024-04-10 11:23:00.122] | Success | <FACET_4.1> computational sequence is valid!
# [2024-04-10 11:23:00.123] | Success | Computational sequence read from file C:/Users/Administrator/PycharmProjects/demo1/deployed\CMU_MOSI_COVAREP.csd ...
# [2024-04-10 11:23:00.182] | Status  | Checking the integrity of the <COVAREP> computational sequence ...
# [2024-04-10 11:23:00.182] | Status  | Checking the format of the data in <COVAREP> computational sequence ...
# [2024-04-10 11:23:00.972] | Success | <COVAREP> computational sequence data in correct format.
# [2024-04-10 11:23:00.972] | Status  | Checking the format of the metadata in <COVAREP> computational sequence ...
# [2024-04-10 11:23:00.972] | Success | <COVAREP> computational sequence metadata in correct format.
# [2024-04-10 11:23:00.972] | Success | <COVAREP> computational sequence is valid!
# [2024-04-10 11:23:00.972] | Success | Computational sequence read from file C:/Users/Administrator/PycharmProjects/demo1/deployed\CMU_MOSI_Opinion_Labels.csd ...
# [2024-04-10 11:23:01.034] | Status  | Checking the integrity of the <Opinion Segment Labels> computational sequence ...
# [2024-04-10 11:23:01.034] | Status  | Checking the format of the data in <Opinion Segment Labels> computational sequence ...
# [2024-04-10 11:23:01.812] | Success | <Opinion Segment Labels> computational sequence data in correct format.
# [2024-04-10 11:23:01.812] | Status  | Checking the format of the metadata in <Opinion Segment Labels> computational sequence ...
# [2024-04-10 11:23:01.812] | Success | <Opinion Segment Labels> computational sequence metadata in correct format.
# [2024-04-10 11:23:01.812] | Success | <Opinion Segment Labels> computational sequence is valid!
# [2024-04-10 11:23:01.812] | Success | Dataset initialized successfully ...
# 1iG0909rllw[12]
# [2024-04-10 11:23:01.813] | Status  | Hard unify was called ...
# [2024-04-10 11:23:01.816] | Success | Hard unify completed ...
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_27548\3465527104.py:74: RuntimeWarning: invalid value encountered in divide
#   (acoustic - acoustic.mean(0, keepdims=True)) / (EPS + np.std(acoustic, axis=0, keepdims=True)))
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_27548\3465527104.py:72: RuntimeWarning: invalid value encountered in divide
#   visual = np.nan_to_num((visual - visual.mean(0, keepdims=True)) / (EPS + np.std(visual, axis=0, keepdims=True)))
# F:\ProgramData\anaconda3\envs\deeplearning\lib\site-packages\numpy\core\_methods.py:176: RuntimeWarning: overflow encountered in multiply
#   x = um.multiply(x, x, out=x)
# F:\ProgramData\anaconda3\envs\deeplearning\lib\site-packages\numpy\core\_methods.py:118: RuntimeWarning: overflow encountered in reduce
#   ret = umr_sum(arr, axis, dtype, out, keepdims, where=where)
# F:\ProgramData\anaconda3\envs\deeplearning\lib\site-packages\numpy\core\_methods.py:152: RuntimeWarning: overflow encountered in reduce
#   arrmean = umr_sum(arr, axis, dtype, keepdims=True, where=where)
# Total number of 0 datapoints have been dropped.
# F:\ProgramData\anaconda3\envs\deeplearning\lib\site-packages\torch\optim\lr_scheduler.py:143: UserWarning: Detected call of `lr_scheduler.step()` before `optimizer.step()`. In PyTorch 1.1.0 and later, you should call them in the opposite order: `optimizer.step()` before `lr_scheduler.step()`.  Failure to do this will result in PyTorch skipping the first value of the learning rate schedule. See more details at https://pytorch.org/docs/stable/optim.html#how-to-adjust-learning-rate
#   warnings.warn("Detected call of `lr_scheduler.step()` before `optimizer.step()`. "
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_27548\3465527104.py:236: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
#   train_iter = tqdm_notebook(train_loader)
#   0%|          | 0/23 [00:00<?, ?it/s]
# Training loss: 1.3245
# Validation loss: 1.3952
# Current patience: 8, current trial: 3.
# Found new best model on dev set!
#   0%|          | 0/23 [00:00<?, ?it/s]
# Training loss: 0.996
# Validation loss: 1.3571
# Current patience: 8, current trial: 3.
# Found new best model on dev set!
#   0%|          | 0/23 [00:00<?, ?it/s]
# Training loss: 0.7808
# Validation loss: 1.3119
# Current patience: 8, current trial: 3.
# Found new best model on dev set!
#   0%|          | 0/23 [00:00<?, ?it/s]
# Training loss: 0.6301
# Validation loss: 1.29
# Current patience: 8, current trial: 3.
# Found new best model on dev set!
#   0%|          | 0/23 [00:00<?, ?it/s]
# Training loss: 0.5249
# Validation loss: 1.2898
# Current patience: 8, current trial: 3.
# Found new best model on dev set!
# Test set performance: 1.3105973947152452
# Test set accuracy is 0.5889212827988338
